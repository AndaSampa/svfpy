# %%
from svfpy import svfpy
import numpy as np

# %%
mds = '/media/fernando/DATA/MDS4SVF-Sao-Paulo.tiff'

# %%
svf = svfpy.SVF(mds, '/media/fernando/DATA/svf-sp/', kernel_size_side=2500, tmp_folder='/media/fernando/DATA/svf-sp/')

# %%
svf.downscales()
# Out:
# array([ 1.,  1.,  2.,  2.,  4.,  6., 10., 31.])

# %%
svf.prepare_downscales()
# Out:
# Preparing Downscale, resolution of 0.5
# Preparing Downscale, resolution of 1.0
# Preparing Downscale, resolution of 2.0
# Preparing Downscale, resolution of 3.0
# Preparing Downscale, resolution of 5.0
# Preparing Downscale, resolution of 15.5
# [<xarray.DataArray (band: 1, y: 146905, x: 96008)>
#  [14104055240 values with dtype=float32]
#  Coordinates:
#    * band         (band) int64 1
#    * x            (x) float64 3.129e+05 3.129e+05 ... 3.609e+05 3.609e+05
#    * y            (y) float64 7.417e+06 7.417e+06 ... 7.343e+06 7.343e+06
#      spatial_ref  int64 0
#  Attributes:
#      COLOR_TABLE_RULES_COUNT:   121
#      COLOR_TABLE_RULE_RGB_0:    -1.368651e+03 1.442370e+02 37 57 175 37 57 176
#      COLOR_TABLE_RULE_RGB_1:    1.442370e+02 1.512249e+02 37 57 176 37 58 176
#      COLOR_TABLE_RULE_RGB_10:   6.124286e+02 6.543562e+02 37 62 180 37 62 181
#      COLOR_TABLE_RULE_RGB_100:  1.017729e+03 1.024717e+03 255 246 240 255 247 241
# ...

# %%
svf.svf()
# Out:
# 0 0 0.5
# 0 1 0.5
# 0 2 0.5
# 0 3 0.5
# 0 4 0.5
# 0 5 0.5
# 0 6 0.5
# 0 7 0.5
# 0 8 0.5
# 0 9 0.5
# 0 10 0.5
# 0 11 0.5
# 0 12 0.5
# 0 13 0.5
# 0 14 0.5
# 0 15 0.5
# 0 16 0.5
# 0 17 0.5
# 0 18 0.5
# 0 19 0.5
# 0 20 0.5
# 0 21 0.5
# 0 22 0.5
# 0 23 0.5
# 0 24 0.5
# 0 25 0.5
# 0 26 0.5
# 0 27 0.5
# 0 28 0.5
# 0 29 0.5
# 0 30 0.5
# 0 31 0.5
# 0 32 0.5
# 0 33 0.5
# 0 34 0.5
# 0 35 0.5
# 0 36 0.5
# 0 37 0.5
# 0 38 0.5
# 1 0 0.5
# 1 1 0.5
# 1 2 0.5
# 1 3 0.5
# 1 4 0.5
# 1 5 0.5
# 1 6 0.5
# 1 7 0.5
# 1 8 0.5
# 1 9 0.5
# 1 10 0.5
# 1 11 0.5
# 1 12 0.5
# 1 13 0.5
# 1 14 0.5
# 1 15 0.5
# 1 16 0.5
# 1 17 0.5
# 1 18 0.5
# 1 19 0.5
# 1 20 0.5
# 1 21 0.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/fernando/dev/svfpy/processiing-sao-paulo.ipynb Cell 7 in <cell line: 1>()
# ...

# %%
seila = np.arange(16)

# %%
if seila == None:
    print("seila")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/fernando/dev/svfpy/processiing-sao-paulo.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/fernando/dev/svfpy/processiing-sao-paulo.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> if seila == None:
#       <a href='vscode-notebook-cell:/home/fernando/dev/svfpy/processiing-sao-paulo.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>     print("seila")
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
seila = None

# %%
seila.__class__ == "NoneType"
# Out:
# False

# %%
# Out:
# NoneType

# %%
import rioxarray
import rasterio
import numpy as np
# import dask

# %%
rasterio.open('data/raster/MDS_sampa-ZSTD.tif')
# Out:
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:302, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:213, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:217, in rasterio._err.exc_wrap_pointer()
#
# CPLE_AppDefinedError: data/raster/MDS_sampa-ZSTD.tif: Cannot open TIFF file due to missing codec.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# /media/fernando/1 TB/dev/svfpy/big_rasters.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/media/fernando/1%20TB/dev/svfpy/big_rasters.ipynb#ch0000001?line=0'>1</a> rasterio.open('data/raster/MDS_sampa-ZSTD.tif')
#
# ...

# %%
mdt = rioxarray.open_rasterio('data/raster/MDS_sampa-ZSTD.tif', cache=False, chunks=250)

# %%
mdt
# Out:
# <xarray.DataArray (band: 1, y: 146905, x: 96008)>
# dask.array<open_rasterio-6813922e2836055b706009e7cb67ba91<this-array>, shape=(1, 146905, 96008), dtype=float32, chunksize=(1, 250, 250), chunktype=numpy.ndarray>
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 3.129e+05 3.129e+05 ... 3.609e+05 3.609e+05
#   * y            (y) float64 7.417e+06 7.417e+06 ... 7.343e+06 7.343e+06
#     spatial_ref  int64 0
# Attributes:
#     COLOR_TABLE_RULES_COUNT:   121
#     COLOR_TABLE_RULE_RGB_0:    -1.368651e+03 1.442370e+02 37 57 175 37 57 176
#     COLOR_TABLE_RULE_RGB_1:    1.442370e+02 1.512249e+02 37 57 176 37 58 176
#     COLOR_TABLE_RULE_RGB_10:   6.124286e+02 6.543562e+02 37 62 180 37 62 181
#     COLOR_TABLE_RULE_RGB_100:  1.017729e+03 1.024717e+03 255 246 240 255 247 241
#     COLOR_TABLE_RULE_RGB_101:  1.024717e+03 1.031705e+03 255 247 241 255 247 242
#     COLOR_TABLE_RULE_RGB_102:  1.031705e+03 1.035199e+03 255 247 242 255 248 242
# ...

# %%
seila = mdt[0, [25000, 25002, 25004], [25000, 25002, 25004]].values

# %%
seila
# Out:
# array([[859.58, 863.3 , 865.7 ],
#        [861.72, 865.18, 866.46],
#        [858.9 , 863.6 , 863.49]], dtype=float32)

# %%
mdt.shape
# Out:
# (1, 146905, 96008)

# %%
seila = mdt.values
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /home/fernando/dev/svfpy/big_rasters.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/fernando/dev/svfpy/big_rasters.ipynb#ch0000003?line=0'>1</a> seila = mdt.values
#
# File ~/dev/svfpy/venv/lib/python3.10/site-packages/xarray/core/dataarray.py:685, in DataArray.values(self)
#     676 @property
#     677 def values(self) -> np.ndarray:
#     678     """
#     679     The array's data as a numpy.ndarray.
#     680
#    (...)
#     683     type does not support coercion like this (e.g. cupy).
#     684     """
# --> 685     return self.variable.values
#
# File ~/dev/svfpy/venv/lib/python3.10/site-packages/xarray/core/variable.py:527, in Variable.values(self)
#     524 @property
#     525 def values(self):
#     526     """The variable's data as a numpy.ndarray"""
# ...
